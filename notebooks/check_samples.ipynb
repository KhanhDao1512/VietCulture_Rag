# %%
import json
import pandas as pd

with open("output_benchmark.json") as f:
    data = json.load(f)

df = pd.DataFrame(data)

# Kiểm tra phân bố
print(df['category'].value_counts())
print(df['difficulty'].value_counts())
print(df['question_type'].value_counts())
# Out:
# category
# am_thuc                  20
# doi_song_hang_ngay       20
# giao_thong               20
# kien_truc                20
# le_hoi                   20
# nhac_cu                  20
# phong_canh               20
# the_thao_truyen_thong    20
# thu_cong_my_nghe         20
# trang_phuc               20
# tro_choi_dan_gian        20
# van_hoa_dan_gian         20
# Name: count, dtype: int64
# difficulty
# medium    133
# hard      107
# Name: count, dtype: int64
# question_type
# cultural       93
# analysis       59
# comparison     52
# description    36
# Name: count, dtype: int64
